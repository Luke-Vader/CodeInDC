# %%
import nltk

# %%
from nltk import bigrams

# %%
sent2 = ['It', 'is', 'NLP', 'Class', 'which', 'is', 'defined', 'as', 'CSIS', '3400', '-', '001', 'in', 'Douglas', 'College']

# %%
len(sent2)
# Out:
# 15

# %%
nltk.bigrams(sent2)
# Out:
# <generator object bigrams at 0x0000022967C1BE60>

# %%
list(bigrams(sent2))
# Out:
# [('It', 'is'),
#  ('is', 'NLP'),
#  ('NLP', 'Class'),
#  ('Class', 'which'),
#  ('which', 'is'),
#  ('is', 'defined'),
#  ('defined', 'as'),
#  ('as', 'CSIS'),
#  ('CSIS', '3400'),
#  ('3400', '-'),
#  ('-', '001'),
#  ('001', 'in'),
#  ('in', 'Douglas'),
#  ('Douglas', 'College')]

# %%
from nltk.probability import FreqDist
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\300374594\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
f1 = open('C:/Users/300374594/Downloads/sample.txt', newline = '')

# %%
raw = f1.read()

# %%
token = nltk.word_tokenize(raw)

# %%
text1 = nltk.Text(token)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\300374594\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
text1.collocations()
# Out:
# Apache Kafka; high volumes; fault tolerance; data processing;
# operational complexity; use cases; longer retention; real-time data;
# Fault Tolerance; Future Directions; Use Cases; learning curve; low
# latency; steep learning; large-scale deployments; Kafka Streams;
# client libraries; message consumption; message ordering; distributed
# nature

# %%
[len(w) for w in text1]
# Out:
# [9,
#  7,
#  6,
#  5,
#  2,
#  2,
#  11,
#  11,
#  5,
#  9,
#  8,
#  4,
#  3,
#  14,
#  3,
#  3,
#  10,
#  6,
#  9,
#  4,
#  1,
#  9,
#  9,
#  2,
#  8,
#  2,
#  6,
#  4,
#  7,
#  2,
#  4,
#  1,
#  5,
#  2,
#  3,
#  8,
#  2,
#  1,
#  6,
#  2,
#  10,
#  3,
#  3,
#  4,
#  10,
#  1,
#  11,
#  1,
#  3,
#  5,
#  9,
#  1,
#  2,
#  9,
#  2,
#  1,
#  6,
#  9,
#  3,
#  9,
#  4,
#  9,
#  1,
#  8,
#  12,
#  2,
#  7,
#  1,
#  9,
#  2,
#  1,
#  7,
#  1,
#  3,
#  7,
#  10,
#  7,
#  2,
#  4,
#  1,
#  4,
#  3,
#  7,
#  2,
#  10,
#  9,
#  15,
#  3,
#  11,
#  10,
#  1,
#  5,
#  3,
#  6,
#  1,
#  8,
#  9,
#  2,
#  6,
#  4,
#  13,
#  1,
#  8,
#  1,
#  8,
#  2,
#  3,
#  7,
#  10,
#  2,
#  3,
#  4,
#  10,
#  1,
#  8,
#  3,
#  3,
#  11,
#  1,
#  5,
#  3,
#  6,
#  7,
#  7,
#  2,
#  6,
#  3,
#  2,
#  8,
#  2,
#  7,
#  8,
#  8,
#  1,
#  6,
#  2,
#  2,
#  9,
#  4,
#  3,
#  10,
#  7,
#  2,
#  8,
#  9,
#  9,
#  3,
#  12,
#  10,
#  1,
#  2,
#  3,
#  7,
#  9,
#  7,
#  1,
#  5,
#  9,
#  2,
#  5,
#  1,
#  8,
#  3,
# ...

# %%
f1 = FreqDist([len(w) for w in text1])

# %%
f1
# Out:
# FreqDist({1: 371, 3: 308, 2: 266, 7: 234, 4: 228, 5: 190, 9: 183, 8: 179, 6: 168, 10: 116, ...})

# %%
f1.keys()
# Out:
# dict_keys([9, 7, 6, 5, 2, 11, 8, 4, 3, 14, 10, 1, 12, 15, 13, 16, 17, 21, 18])

# %%
f1.max()
# Out:
# 1

# %%
f1[3]
# Out:
# 308

# %%
f1.freq(5)
# Out:
# 0.07796471070988921

# %%
[w.upper() for w in text1]
# Out:
# ['EXECUTIVE',
#  'SUMMARY',
#  'APACHE',
#  'KAFKA',
#  'IS',
#  'AN',
#  'OPEN-SOURCE',
#  'DISTRIBUTED',
#  'EVENT',
#  'STREAMING',
#  'PLATFORM',
#  'THAT',
#  'HAS',
#  'REVOLUTIONIZED',
#  'THE',
#  'WAY',
#  'BUSINESSES',
#  'HANDLE',
#  'REAL-TIME',
#  'DATA',
#  '.',
#  'INITIALLY',
#  'DEVELOPED',
#  'AT',
#  'LINKEDIN',
#  'TO',
#  'MANAGE',
#  'HIGH',
#  'VOLUMES',
#  'OF',
#  'DATA',
#  ',',
#  'KAFKA',
#  'IS',
#  'NOW',
#  'EMBRACED',
#  'BY',
#  'A',
#  'MYRIAD',
#  'OF',
#  'INDUSTRIES',
#  'FOR',
#  'ITS',
#  'HIGH',
#  'THROUGHPUT',
#  ',',
#  'SCALABILITY',
#  ',',
#  'AND',
#  'FAULT',
#  'TOLERANCE',
#  '.',
#  'IT',
#  'FUNCTIONS',
#  'AS',
#  'A',
#  'ROBUST',
#  'FRAMEWORK',
#  'FOR',
#  'STREAMING',
#  'DATA',
#  'PIPELINES',
#  ',',
#  'ENABLING',
#  'APPLICATIONS',
#  'TO',
#  'PUBLISH',
#  ',',
#  'SUBSCRIBE',
#  'TO',
#  ',',
#  'PROCESS',
#  ',',
#  'AND',
#  'ANALYZE',
#  'CONTINUOUS',
#  'STREAMS',
#  'OF',
#  'DATA',
#  '.',
#  'WITH',
#  'ITS',
# ...

# %%
len(set([word.lower() for word in text1]))
# Out:
# 694

# %%
len(set([word.lower() for word in text1 if word.isalpha()]))
# Out:
# 653

# %%
sent2 = ['call', 'me', 'Jane', 'after', 'the', 'work', 'but', 'before', 'the', 'evening', 'I', 'must', 'go', 'to', 'the', 'gym', '.']

# %%
for token in sent2:
    if token.islower():
        print(token + ' is a lowercase token')
    elif token.istitle():
        print(token + ' is a titlecase token')
    else:
        print(token + ' is a punctuation')
# Out:
# call is a lowercase token
# me is a lowercase token
# Jane is a titlecase token
# after is a lowercase token
# the is a lowercase token
# work is a lowercase token
# but is a lowercase token
# before is a lowercase token
# the is a lowercase token
# evening is a lowercase token
# I is a titlecase token
# must is a lowercase token
# go is a lowercase token
# to is a lowercase token
# the is a lowercase token
# gym is a lowercase token
# . is a punctuation

# %%
from nltk.corpus import PlaintextCorpusReader

# %%
corpus_root = 'C:/Users/300374594/Downloads'

# %%
wordlists = PlaintextCorpusReader(corpus_root, '.*')

# %%
wordlists.fileids()
# Out:
# ['desktop.ini',
#  'sample - Copy - Copy - Copy - Copy.txt',
#  'sample - Copy - Copy - Copy.txt',
#  'sample - Copy - Copy.txt',
#  'sample - Copy.txt',
#  'sample.txt']

# %%
wordlists.words('sample.txt')
# Out:
# ['Executive', 'Summary', 'Apache', 'Kafka', 'is', 'an', ...]

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\300374594\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = nltk.corpus.gutenberg.words('austen-emma.txt')

# %%
len(emma)
# Out:
# 192427

# %%
len(set(emma))
# Out:
# 7811

# %%
from nltk.corpus import gutenberg

# %%
for fileid in gutenberg.fileids():
    chars = len(gutenberg.raw(fileid))
    words = len(gutenberg.words(fileid))
    sentences = len(gutenberg.sents(fileid))
    vocab = len(set([w.lower() for w in gutenberg.words(fmacbileid)]))
    print(int(chars/words), int(words/sentences), int(words/vocab), fileid)
# Out:
# 4 24 26 austen-emma.txt
# 4 26 16 austen-persuasion.txt
# 4 28 22 austen-sense.txt
# 4 33 79 bible-kjv.txt
# 4 19 5 blake-poems.txt
# 4 19 14 bryant-stories.txt
# 4 17 12 burgess-busterbrown.txt
# 4 20 12 carroll-alice.txt
# 4 20 11 chesterton-ball.txt
# 4 22 11 chesterton-brown.txt
# 4 18 10 chesterton-thursday.txt
# 4 20 24 edgeworth-parents.txt
# 4 25 15 melville-moby_dick.txt
# 4 52 10 milton-paradise.txt
# 4 11 8 shakespeare-caesar.txt
# 4 12 7 shakespeare-hamlet.txt
# 4 12 6 shakespeare-macbeth.txt
# 4 36 12 whitman-leaves.txt

# %%
macbeth_sentences = gutenberg.sents('shakespeare-macbeth.txt')

# %%
macbeth_sentences
# Out:
# [['[', 'The', 'Tragedie', 'of', 'Macbeth', 'by', 'William', 'Shakespeare', '1603', ']'], ['Actus', 'Primus', '.'], ...]

# %%
nltk.download('webtext')
# Out:
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\300374594\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\webtext.zip.
# True

# %%
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\300374594\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# True

# %%
from nltk.corpus import webtext

# %%
for fileid in webtext.fileids():
    print(fileid, webtext.raw(fileid)[:65], '...')
# Out:
# firefox.txt Cookie Manager: "Don't allow sites that set removed cookies to se ...
# grail.txt SCENE 1: [wind] [clop clop clop]
# KING ARTHUR: Whoa there!  [clop ...
# overheard.txt White guy: So, do you have any plans for this evening?
# Asian girl ...
# pirates.txt PIRATES OF THE CARRIBEAN: DEAD MAN'S CHEST, by Ted Elliott & Terr ...
# singles.txt 25 SEXY MALE, seeks attrac older single lady, for discreet encoun ...
# wine.txt Lovely delicate, fragrant Rhone wine. Polished leather and strawb ...

# %%
from nltk.corpus import brown

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
brown.words(categories = 'news')
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
brown.sents(categories = ['news', 'editorial', 'reviews'])
# Out:
# [['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.'], ['The', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.'], ...]

# %%
brown.words(fileids = ['cg22'])
# Out:
# ['Does', 'our', 'society', 'have', 'a', 'runaway', ',', ...]

# %%
nltk.download('reuters')
# Out:
# [nltk_data] Downloading package reuters to
# [nltk_data]     C:\Users\300374594\AppData\Roaming\nltk_data...
# True

# %%
from nltk.corpus import reuters

# %%
reuters.categories()
# Out:
# ['acq',
#  'alum',
#  'barley',
#  'bop',
#  'carcass',
#  'castor-oil',
#  'cocoa',
#  'coconut',
#  'coconut-oil',
#  'coffee',
#  'copper',
#  'copra-cake',
#  'corn',
#  'cotton',
#  'cotton-oil',
#  'cpi',
#  'cpu',
#  'crude',
#  'dfl',
#  'dlr',
#  'dmk',
#  'earn',
#  'fuel',
#  'gas',
#  'gnp',
#  'gold',
#  'grain',
#  'groundnut',
#  'groundnut-oil',
#  'heat',
#  'hog',
#  'housing',
#  'income',
#  'instal-debt',
#  'interest',
#  'ipi',
#  'iron-steel',
#  'jet',
#  'jobs',
#  'l-cattle',
#  'lead',
#  'lei',
#  'lin-oil',
#  'livestock',
#  'lumber',
#  'meal-feed',
#  'money-fx',
#  'money-supply',
#  'naphtha',
#  'nat-gas',
#  'nickel',
#  'nkr',
#  'nzdlr',
#  'oat',
#  'oilseed',
#  'orange',
#  'palladium',
#  'palm-oil',
#  'palmkernel',
#  'pet-chem',
#  'platinum',
#  'potato',
#  'propane',
#  'rand',
#  'rape-oil',
#  'rapeseed',
#  'reserves',
#  'retail',
#  'rice',
#  'rubber',
#  'rye',
#  'ship',
#  'silver',
#  'sorghum',
#  'soy-meal',
#  'soy-oil',
# ...

# %%
reuters.fileids()
# Out:
# ['test/14826',
#  'test/14828',
#  'test/14829',
#  'test/14832',
#  'test/14833',
#  'test/14839',
#  'test/14840',
#  'test/14841',
#  'test/14842',
#  'test/14843',
#  'test/14844',
#  'test/14849',
#  'test/14852',
#  'test/14854',
#  'test/14858',
#  'test/14859',
#  'test/14860',
#  'test/14861',
#  'test/14862',
#  'test/14863',
#  'test/14865',
#  'test/14867',
#  'test/14872',
#  'test/14873',
#  'test/14875',
#  'test/14876',
#  'test/14877',
#  'test/14881',
#  'test/14882',
#  'test/14885',
#  'test/14886',
#  'test/14888',
#  'test/14890',
#  'test/14891',
#  'test/14892',
#  'test/14899',
#  'test/14900',
#  'test/14903',
#  'test/14904',
#  'test/14907',
#  'test/14909',
#  'test/14911',
#  'test/14912',
#  'test/14913',
#  'test/14918',
#  'test/14919',
#  'test/14921',
#  'test/14922',
#  'test/14923',
#  'test/14926',
#  'test/14928',
#  'test/14930',
#  'test/14931',
#  'test/14932',
#  'test/14933',
#  'test/14934',
#  'test/14941',
#  'test/14943',
# ...

# %%
reuters.categories(['training/9865', 'training/9880'])
# Out:
# ['barley', 'corn', 'grain', 'money-fx', 'wheat']

# %%
reuters.fileids('barley')
# Out:
# ['test/15618',
#  'test/15649',
#  'test/15676',
#  'test/15728',
#  'test/15871',
#  'test/15875',
#  'test/15952',
#  'test/17767',
#  'test/17769',
#  'test/18024',
#  'test/18263',
#  'test/18908',
#  'test/19275',
#  'test/19668',
#  'training/10175',
#  'training/1067',
#  'training/11208',
#  'training/11316',
#  'training/11885',
#  'training/12428',
#  'training/13099',
#  'training/13744',
#  'training/13795',
#  'training/13852',
#  'training/13856',
#  'training/1652',
#  'training/1970',
#  'training/2044',
#  'training/2171',
#  'training/2172',
#  'training/2191',
#  'training/2217',
#  'training/2232',
#  'training/3132',
#  'training/3324',
#  'training/395',
#  'training/4280',
#  'training/4296',
#  'training/5',
#  'training/501',
#  'training/5467',
#  'training/5610',
#  'training/5640',
#  'training/6626',
#  'training/7205',
#  'training/7579',
#  'training/8213',
#  'training/8257',
#  'training/8759',
#  'training/9865',
#  'training/9958']

# %%
from nltk.corpus import inaugural

# %%
nltk.download('inaugural')
# Out:
# [nltk_data] Downloading package inaugural to
# [nltk_data]     C:\Users\300374594\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\inaugural.zip.
# True

# %%
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...
